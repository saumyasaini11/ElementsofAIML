# %% [markdown]
# <a href="https://colab.research.google.com/github/saumyasaini11/ElementsofAIML/blob/main/AIML_LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# implement the misssing values , and outline handling data preprocessing techniques on the dataset imported in lab 1

# %%
from google.colab import files
ss=files.upload()
# Out:
#      <input type="file" id="files-72299f6f-16ee-4458-8971-6cc93bd3b3b2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72299f6f-16ee-4458-8971-6cc93bd3b3b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import pandas as pd
import numpy as np

# !pip install scikit-learn

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn import preprocessing
from sklearn.model_selection import train_test_split, cross_val_score,StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.impute import KNNImputer

import missingno as msno
pd.read_csv("supermarket_sales1.csv")
# Out:
# ...
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A        NaN        Member  Female
# 1    226-31-3081    NaN  Naypyitaw        Normal     N/A
# 2    631-41-3108      A        NaN        Normal    Male
# 3    123-19-1176      A     Yangon        Member     NaN
# 4    373-73-7910    NaN     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0                       NaN       74.69       7.0      NaN   548.9715
# 1    Electronic accessories         NaN       5.0   3.8200        NaN
# ...

# %%
data=pd.read_csv("supermarket_sales1.csv")
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A        NaN        Member  Female
# 1  226-31-3081    NaN  Naypyitaw        Normal     N/A
# 2  631-41-3108      A        NaN        Normal    Male
# 3  123-19-1176      A     Yangon        Member     NaN
# 4  373-73-7910    NaN     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0                     NaN       74.69       7.0      NaN  548.9715
# 1  Electronic accessories         NaN       5.0   3.8200       NaN
# 2      Home and lifestyle       46.33       NaN  16.2155  340.5255
# 3       Health and beauty         NaN       8.0  23.2880  489.0480
# 4       Sports and travel       86.31       7.0  30.2085       NaN
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1         NaN  10:29         Cash     NaN                 4.761905
# ...

# %%
data['Tax 5%'].fillna(data['Tax 5%'].mode()[0],inplace=True)
data.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A        NaN        Member  Female
# 1  226-31-3081    NaN  Naypyitaw        Normal     N/A
# 2  631-41-3108      A        NaN        Normal    Male
# 3  123-19-1176      A     Yangon        Member     NaN
# 4  373-73-7910    NaN     Yangon        Normal    Male
# 5  699-14-3026      C        NaN        Normal    Male
# 6  355-53-5943    NaN     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0                     NaN       74.69       7.0   4.1540  548.9715
# 1  Electronic accessories       83.77       5.0   3.8200       NaN
# 2      Home and lifestyle       46.33       NaN  16.2155  340.5255
# 3       Health and beauty       83.77       8.0  23.2880  489.0480
# ...

# %%
data['Unit price'].fillna(data['Unit price'].mean(),inplace=True)
data.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A        NaN        Member  Female
# 1  226-31-3081    NaN  Naypyitaw        Normal     N/A
# 2  631-41-3108      A        NaN        Normal    Male
# 3  123-19-1176      A     Yangon        Member     NaN
# 4  373-73-7910    NaN     Yangon        Normal    Male
# 5  699-14-3026      C        NaN        Normal    Male
# 6  355-53-5943    NaN     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0                     NaN       74.69       7.0   4.1540  548.9715
# 1  Electronic accessories       83.77       5.0   3.8200       NaN
# 2      Home and lifestyle       46.33       NaN  16.2155  340.5255
# 3       Health and beauty       83.77       8.0  23.2880  489.0480
# ...

# %%
data['Unit price'].fillna(data['Unit price'].median(),inplace=True)
data.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A        NaN        Member  Female
# 1  226-31-3081    NaN  Naypyitaw        Normal     N/A
# 2  631-41-3108      A        NaN        Normal    Male
# 3  123-19-1176      A     Yangon        Member     NaN
# 4  373-73-7910    NaN     Yangon        Normal    Male
# 5  699-14-3026      C        NaN        Normal    Male
# 6  355-53-5943    NaN     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0                     NaN       74.69       7.0   4.1540  548.9715
# 1  Electronic accessories       83.77       5.0   3.8200       NaN
# 2      Home and lifestyle       46.33       NaN  16.2155  340.5255
# 3       Health and beauty       83.77       8.0  23.2880  489.0480
# ...

# %%
data['Tax 5%'].fillna(data['Tax 5%'].mean(),inplace=True)
data.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A        NaN        Member  Female
# 1  226-31-3081    NaN  Naypyitaw        Normal     N/A
# 2  631-41-3108      A        NaN        Normal    Male
# 3  123-19-1176      A     Yangon        Member     NaN
# 4  373-73-7910    NaN     Yangon        Normal    Male
# 5  699-14-3026      C        NaN        Normal    Male
# 6  355-53-5943    NaN     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0                     NaN       74.69       7.0   4.1540  548.9715
# 1  Electronic accessories       83.77       5.0   3.8200       NaN
# 2      Home and lifestyle       46.33       NaN  16.2155  340.5255
# 3       Health and beauty       83.77       8.0  23.2880  489.0480
# ...

# %%
Q1=data['Unit price'].quantile(0.25)
Q1
# Out:
# 44.620000000000005

# %%
Q3=data['Unit price'].quantile(0.75)
Q3
# Out:
# 68.0225

# %%
IQR=Q3-Q1
IQR
# Out:
# 23.40249999999999

# %%
lower_bound=Q1
lower_bound
#lower_bound=Q1+1.5 or can do more operations here
#lower_bound
# Out:
# 44.620000000000005

# %%
upper_bound=Q3
upper_bound
# Out:
# 68.0225

# %%
data=data[(data['Unit price']>lower_bound)&(data['Unit price']<upper_bound)]
data.head(10)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A        NaN        Member  Female
# 2   631-41-3108      A        NaN        Normal    Male
# 6   355-53-5943    NaN     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 16  656-95-9349      A     Yangon        Member  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 0                      NaN       74.69       7.0   4.1540  548.9715
# 2       Home and lifestyle       46.33       NaN  16.2155  340.5255
# 6   Electronic accessories       68.84       6.0  20.6520  433.6920
# 7       Home and lifestyle       73.56       NaN  36.7800  772.3800
# ...

# %%
data['Unit price']=np.where(data['Unit price']>upper_bound,upper_bound,data['Unit price'])
data.head(10)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A        NaN        Member  Female
# 2   631-41-3108      A        NaN        Normal    Male
# 6   355-53-5943    NaN     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 16  656-95-9349      A     Yangon        Member  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 0                      NaN     68.0225       7.0   4.1540  548.9715
# 2       Home and lifestyle     46.3300       NaN  16.2155  340.5255
# 6   Electronic accessories     68.0225       6.0  20.6520  433.6920
# 7       Home and lifestyle     68.0225       NaN  36.7800  772.3800
# ...

# %%
data['Unit price']=np.where(data['Unit price']<lower_bound,lower_bound,data['Unit price'])
data.head(10)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A        NaN        Member  Female
# 2   631-41-3108      A        NaN        Normal    Male
# 6   355-53-5943    NaN     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 16  656-95-9349      A     Yangon        Member  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 0                      NaN     68.0225       7.0   4.1540  548.9715
# 2       Home and lifestyle     46.3300       NaN  16.2155  340.5255
# 6   Electronic accessories     68.0225       6.0  20.6520  433.6920
# 7       Home and lifestyle     68.0225       NaN  36.7800  772.3800
# ...

# %%
data['Unit price']=np.log(data['Unit price'])
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A        NaN        Member  Female
# 2    631-41-3108      A        NaN        Normal    Male
# 6    355-53-5943    NaN     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 991  602-16-6955      B   Mandalay        Normal  Female
# 992  745-74-0715      A     Yangon        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 998  347-56-2442      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0                       NaN    4.219839       7.0   4.1540  548.9715
# 2        Home and lifestyle    3.835790       NaN  16.2155  340.5255
# 6    Electronic accessories    4.219839       6.0  20.6520  433.6920
# ...

# %%
##read about KNN and research in next class
